# %%
from create_spacenet_masks import create_masks

# %%
# create masks and conver 48 bit-depth images to 24 bit-depth
file_path = r"F:\CPLN_680_Data\SN3_roads_train_AOI_4_Shanghai\AOI_4_Shanghai"
create_masks(path_data = file_path)
# Out:
#  1 / 1198
#   im_name: SN3_roads_train_AOI_4_Shanghai_PS-RGB_img10.tif
#   name_root: AOI_4_Shanghai_geojson_roads_img10
#   im_file_out: F:\CPLN_680_Data\SN3_roads_train_AOI_4_Shanghai\AOI_4_Shanghai\PS-RGB_8bit\SN3_roads_train_AOI_4_Shanghai_PS-RGB_img10.tif
#   mask_file: F:\CPLN_680_Data\SN3_roads_train_AOI_4_Shanghai\AOI_4_Shanghai\masks_xm\AOI_4_Shanghai_geojson_roads_img10.png
#   output_plot_file: F:\CPLN_680_Data\SN3_roads_train_AOI_4_Shanghai\AOI_4_Shanghai\masks_xm_plots\AOI_4_Shanghai_geojson_roads_img10.png
#
#  2 / 1198
#   im_name: SN3_roads_train_AOI_4_Shanghai_PS-RGB_img100.tif
#   name_root: AOI_4_Shanghai_geojson_roads_img100
#   im_file_out: F:\CPLN_680_Data\SN3_roads_train_AOI_4_Shanghai\AOI_4_Shanghai\PS-RGB_8bit\SN3_roads_train_AOI_4_Shanghai_PS-RGB_img100.tif
#   mask_file: F:\CPLN_680_Data\SN3_roads_train_AOI_4_Shanghai\AOI_4_Shanghai\masks_xm\AOI_4_Shanghai_geojson_roads_img100.png
# ...
